# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt

# %% [markdown]
# region1(30~50km/s)

# %% [markdown]
# region1(50~70km/s)

# %% [markdown]
# region1(70~100km/s)

# %% [markdown]
# region1(-100~-70km/s)

# %% [markdown]
# region1(-70~-50km/s)

# %% [markdown]
# region1(-50~-30km/s)

# %%
fil_ori_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/ori_test_1_30_50.npy")
fil_int_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/tot_int_test_1_30_50.npy")
fil_popt_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/popt_test_1_30_50.npy")
fil_pcov_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/pcov_test_1_30_50.npy")

fil_ori_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/ori_test_1_50_70.npy")
fil_int_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/tot_int_test_1_50_70.npy")
fil_popt_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/popt_test_1_50_70.npy")
fil_pcov_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/pcov_test_1_50_70.npy")

fil_ori_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/ori_test_1_70_100.npy")
fil_int_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/tot_int_test_1_70_100.npy")
fil_popt_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/popt_test_1_70_100.npy")
fil_pcov_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/pcov_test_1_70_100.npy")

fil_ori_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/ori_test_1_-100_-70.npy")
fil_int_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/tot_int_test_1_-100_-70.npy")
fil_popt_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/popt_test_1_-100_-70.npy")
fil_pcov_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/pcov_test_1_-100_-70.npy")

fil_ori_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/ori_test_1_-70_-50.npy")
fil_int_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/tot_int_test_1_-70_-50.npy")
fil_popt_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/popt_test_1_-70_-50.npy")
fil_pcov_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/pcov_test_1_-70_-50.npy")

fil_ori_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/ori_test_1_-50_-30.npy")
fil_int_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/tot_int_test_1_-50_-30.npy")
fil_popt_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/popt_test_1_-50_-30.npy")
fil_pcov_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region1/pcov_test_1_-50_-30.npy")

# %%
# list = [
#   [fil_ori_1, fil_int_1, fil_popt_1, fil_pcov_1], 
#   [fil_ori_2, fil_int_2, fil_popt_2, fil_pcov_2],
#   [fil_ori_3, fil_int_3, fil_popt_3, fil_pcov_3], 
#   [fil_ori_4, fil_int_4, fil_popt_4, fil_pcov_4], 
#   [fil_ori_5, fil_int_5, fil_popt_5, fil_pcov_5], 
#   [fil_ori_6, fil_int_6, fil_popt_6, fil_pcov_6]
# ]
list = [
  [fil_popt_1[1], fil_popt_1[0],fil_popt_1[1],fil_popt_1[2], [fil_pcov_1[0][0],fil_pcov_1[1][1],fil_pcov_1[2][2]], np.min(fil_int_1),np.max(fil_int_1),np.median(fil_int_1)], 
  [fil_popt_2[1], fil_popt_2[0],fil_popt_2[1],fil_popt_2[2], [fil_pcov_2[0][0],fil_pcov_2[1][1],fil_pcov_2[2][2]], np.min(fil_int_2),np.max(fil_int_2),np.median(fil_int_2)],
  [fil_popt_3[1], fil_popt_3[0],fil_popt_3[1],fil_popt_3[2], [fil_pcov_3[0][0],fil_pcov_3[1][1],fil_pcov_3[2][2]], np.min(fil_int_3),np.max(fil_int_3),np.median(fil_int_3)], 
  [fil_popt_4[1], fil_popt_4[0],fil_popt_4[1],fil_popt_4[2], [fil_pcov_4[0][0],fil_pcov_4[1][1],fil_pcov_4[2][2]], np.min(fil_int_4),np.max(fil_int_4),np.median(fil_int_4)], 
  [fil_popt_5[1], fil_popt_5[0],fil_popt_5[1],fil_popt_5[2], [fil_pcov_5[0][0],fil_pcov_5[1][1],fil_pcov_5[2][2]], np.min(fil_int_5),np.max(fil_int_5),np.median(fil_int_5)], 
  [fil_popt_6[1], fil_popt_6[0],fil_popt_6[1],fil_popt_6[2], [fil_pcov_6[0][0],fil_pcov_6[1][1],fil_pcov_6[2][2]], np.min(fil_int_6),np.max(fil_int_6),np.median(fil_int_6)]
]

# %%
df = pd.DataFrame(list)
df.index = ['30~50km/s','50~70km/s','70~100km/s','-100~-70km/s','-70~-50km/s','-50~-30km/s']
df.columns = ['position angle(mode)','amplitude','offset','sigma','covariance','total intensity(min)','total intensity(max)','total intensity(median)']
df.style.set_caption("lower left")

# df.to_excel("/home/filament/Desktop/region1.xlsx")
# Out:
# <style type="text/css">
# </style>
# <table id="T_52a0a_">
#   <caption>lower left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >position angle(mode)</th>
#       <th class="col_heading level0 col1" >amplitude</th>
#       <th class="col_heading level0 col2" >offset</th>
#       <th class="col_heading level0 col3" >sigma</th>
#       <th class="col_heading level0 col4" >covariance</th>
#       <th class="col_heading level0 col5" >total intensity(min)</th>
#       <th class="col_heading level0 col6" >total intensity(max)</th>
#       <th class="col_heading level0 col7" >total intensity(median)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52a0a_level0_row0" class="row_heading level0 row0" >30~50km/s</th>
#       <td id="T_52a0a_row0_col0" class="data row0 col0" >12.694559</td>
#       <td id="T_52a0a_row0_col1" class="data row0 col1" >13.843568</td>
# ...

# %%
high_int_filament_1 = []
low_int_filament_1 = []
for i in range(len(fil_ori_1)):
    if fil_int_1[i] >= np.median(fil_int_1):
        high_int_filament_1.append(fil_ori_1[i])
    elif fil_int_1[i] < np.median(fil_int_1):
        low_int_filament_1.append(fil_ori_1[i])
        
high_int_filament_2 = []
low_int_filament_2 = []
for i in range(len(fil_ori_2)):
    if fil_int_2[i] >= np.median(fil_int_2):
        high_int_filament_2.append(fil_ori_2[i])
    elif fil_int_2[i] < np.median(fil_int_2):
        low_int_filament_2.append(fil_ori_2[i])
        
high_int_filament_3 = []
low_int_filament_3 = []
for i in range(len(fil_ori_3)):
    if fil_int_3[i] >= np.median(fil_int_3):
        high_int_filament_3.append(fil_ori_3[i])
    elif fil_int_3[i] < np.median(fil_int_3):
        low_int_filament_3.append(fil_ori_3[i])

high_int_filament_4 = []
low_int_filament_4 = []
for i in range(len(fil_ori_4)):
    if fil_int_4[i] >= np.median(fil_int_4):
        high_int_filament_4.append(fil_ori_4[i])
    elif fil_int_4[i] < np.median(fil_int_4):
        low_int_filament_4.append(fil_ori_4[i])
        
high_int_filament_5 = []
low_int_filament_5 = []
for i in range(len(fil_ori_5)):
    if fil_int_5[i] >= np.median(fil_int_5):
        high_int_filament_5.append(fil_ori_5[i])
    elif fil_int_5[i] < np.median(fil_int_5):
        low_int_filament_5.append(fil_ori_5[i])
        
high_int_filament_6 = []
low_int_filament_6 = []
for i in range(len(fil_ori_6)):
    if fil_int_6[i] >= np.median(fil_int_6):
        high_int_filament_6.append(fil_ori_6[i])
    elif fil_int_6[i] < np.median(fil_int_6):
        low_int_filament_6.append(fil_ori_6[i])

# %%
plt.rcParams["font.size"] = 15
plt.title("lower left_-50km/s_-30km/s")
bins = np.linspace(-90,90,num=10)
plt.hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins = bins)
plt.hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins = bins)

plt.rcParams["font.size"] = 10
plt.legend(loc='upper left')

plt.savefig("/home/filament/Desktop/lower left_-50_-30.jpg")

# %%
fig,ax = plt.subplots(3,2,figsize=(16,16))
bins = np.linspace(-90,90,num=10)

ax[0,0].set_title("lower left_30km/s_50km/s")
ax[0,0].hist(high_int_filament_1,alpha = 0.5, label='high intensity',bins = bins)
ax[0,0].hist(low_int_filament_1,alpha = 0.5, label='low intensity',bins = bins)
ax[0,0].legend(loc='upper left')



ax[0,1].set_title("lower left_50km/s_70km/s")
ax[0,1].hist(high_int_filament_2,alpha = 0.5, label='high intensity',bins = bins)
ax[0,1].hist(low_int_filament_2,alpha = 0.5, label='low intensity',bins = bins)
ax[0,1].legend(loc='upper left')

ax[1,0].set_title("lower left_70km/s_100km/s")
ax[1,0].hist(high_int_filament_3,alpha = 0.5, label='high intensity',bins = bins)
ax[1,0].hist(low_int_filament_3,alpha = 0.5, label='low intensity',bins = bins)
ax[1,0].legend(loc='upper left')

ax[1,1].set_title("lower left_-100km/s_-70km/s")
ax[1,1].hist(high_int_filament_4,alpha = 0.5, label='high intensity',bins = bins)
ax[1,1].hist(low_int_filament_4,alpha = 0.5, label='low intensity',bins = bins)
ax[1,1].legend(loc='upper left')

ax[2,0].set_title("lower left_-70km/s_-50km/s")
ax[2,0].hist(high_int_filament_5,alpha = 0.5, label='high intensity',bins = bins)
ax[2,0].hist(low_int_filament_5,alpha = 0.5, label='low intensity',bins = bins)
ax[2,0].legend(loc='upper left')


ax[2,1].set_title("lower left_-50km/s_-30km/s")
ax[2,1].hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins = bins)
ax[2,1].hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins = bins)
ax[2,1].legend(loc='upper left')

# %% [markdown]
# region2(30~50km/s)  lower right
#
# region2(50~70km/s)
#
# region2(70~100km/s)
#
# region2(-100~-70km/s)
#
# region2(-70~-50km/s)
#
# region2(-50~-30km/s)

# %%
fil_ori_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/ori_test_2_30_50.npy")
fil_int_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/tot_int_test_2_30_50.npy")
fil_popt_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/popt_test_2_30_50.npy")
fil_pcov_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/pcov_test_2_30_50.npy")

fil_ori_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/ori_test_2_50_70.npy")
fil_int_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/tot_int_test_2_50_70.npy")
fil_popt_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/popt_test_2_50_70.npy")
fil_pcov_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/pcov_test_2_50_70.npy")

fil_ori_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/ori_test_2_70_100.npy")
fil_int_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/tot_int_test_2_70_100.npy")
fil_popt_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/popt_test_2_70_100.npy")
fil_pcov_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/pcov_test_2_70_100.npy")

fil_ori_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/ori_test_2_-100_-70.npy")
fil_int_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/tot_int_test_2_-100_-70.npy")
fil_popt_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/popt_test_2_-100_-70.npy")
fil_pcov_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/pcov_test_2_-100_-70.npy")

fil_ori_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/ori_test_2_-70_-50.npy")
fil_int_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/tot_int_test_2_-70_-50.npy")
fil_popt_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/popt_test_2_-70_-50.npy")
fil_pcov_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/pcov_test_2_-70_-50.npy")

fil_ori_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/ori_test_2_-50_-30.npy")
fil_int_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/tot_int_test_2_-50_-30.npy")
fil_popt_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/popt_test_2_-50_-30.npy")
fil_pcov_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region2/pcov_test_2_-50_-30.npy")

# %%
list = [
  [fil_popt_1[1], fil_popt_1[0],fil_popt_1[1],fil_popt_1[2], [fil_pcov_1[0][0],fil_pcov_1[1][1],fil_pcov_1[2][2]], np.min(fil_int_1),np.max(fil_int_1),np.median(fil_int_1)], 
  [fil_popt_2[1], fil_popt_2[0],fil_popt_2[1],fil_popt_2[2], [fil_pcov_2[0][0],fil_pcov_2[1][1],fil_pcov_2[2][2]], np.min(fil_int_2),np.max(fil_int_2),np.median(fil_int_2)],
  [fil_popt_3[1], fil_popt_3[0],fil_popt_3[1],fil_popt_3[2], [fil_pcov_3[0][0],fil_pcov_3[1][1],fil_pcov_3[2][2]], np.min(fil_int_3),np.max(fil_int_3),np.median(fil_int_3)], 
  [fil_popt_4[1], fil_popt_4[0],fil_popt_4[1],fil_popt_4[2], [fil_pcov_4[0][0],fil_pcov_4[1][1],fil_pcov_4[2][2]], np.min(fil_int_4),np.max(fil_int_4),np.median(fil_int_4)], 
  [fil_popt_5[1], fil_popt_5[0],fil_popt_5[1],fil_popt_5[2], [fil_pcov_5[0][0],fil_pcov_5[1][1],fil_pcov_5[2][2]], np.min(fil_int_5),np.max(fil_int_5),np.median(fil_int_5)], 
  [fil_popt_6[1], fil_popt_6[0],fil_popt_6[1],fil_popt_6[2], [fil_pcov_6[0][0],fil_pcov_6[1][1],fil_pcov_6[2][2]], np.min(fil_int_6),np.max(fil_int_6),np.median(fil_int_6)]
]

# %%
df = pd.DataFrame(list)
df.index = ['30~50km/s','50~70km/s','70~100km/s','-100~-70km/s','-70~-50km/s','-50~-30km/s']
df.columns = ['position angle(mode)','amplitude','offset','sigma','covariance','total intensity(min)','total intensity(max)','total intensity(median)']
df.style.set_caption("lower right")
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd5f2_">
#   <caption>lower right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >position angle(mode)</th>
#       <th class="col_heading level0 col1" >amplitude</th>
#       <th class="col_heading level0 col2" >offset</th>
#       <th class="col_heading level0 col3" >sigma</th>
#       <th class="col_heading level0 col4" >covariance</th>
#       <th class="col_heading level0 col5" >total intensity(min)</th>
#       <th class="col_heading level0 col6" >total intensity(max)</th>
#       <th class="col_heading level0 col7" >total intensity(median)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd5f2_level0_row0" class="row_heading level0 row0" >30~50km/s</th>
#       <td id="T_fd5f2_row0_col0" class="data row0 col0" >-13.601075</td>
#       <td id="T_fd5f2_row0_col1" class="data row0 col1" >22.073953</td>
# ...

# %%
high_int_filament_1 = []
low_int_filament_1 = []
for i in range(len(fil_ori_1)):
    if fil_int_1[i] >= np.median(fil_int_1):
        high_int_filament_1.append(fil_ori_1[i])
    elif fil_int_1[i] < np.median(fil_int_1):
        low_int_filament_1.append(fil_ori_1[i])
        
high_int_filament_2 = []
low_int_filament_2 = []
for i in range(len(fil_ori_2)):
    if fil_int_2[i] >= np.median(fil_int_2):
        high_int_filament_2.append(fil_ori_2[i])
    elif fil_int_2[i] < np.median(fil_int_2):
        low_int_filament_2.append(fil_ori_2[i])
        
high_int_filament_3 = []
low_int_filament_3 = []
for i in range(len(fil_ori_3)):
    if fil_int_3[i] >= np.median(fil_int_3):
        high_int_filament_3.append(fil_ori_3[i])
    elif fil_int_3[i] < np.median(fil_int_3):
        low_int_filament_3.append(fil_ori_3[i])

high_int_filament_4 = []
low_int_filament_4 = []
for i in range(len(fil_ori_4)):
    if fil_int_4[i] >= np.median(fil_int_4):
        high_int_filament_4.append(fil_ori_4[i])
    elif fil_int_4[i] < np.median(fil_int_4):
        low_int_filament_4.append(fil_ori_4[i])
        
high_int_filament_5 = []
low_int_filament_5 = []
for i in range(len(fil_ori_5)):
    if fil_int_5[i] >= np.median(fil_int_5):
        high_int_filament_5.append(fil_ori_5[i])
    elif fil_int_5[i] < np.median(fil_int_5):
        low_int_filament_5.append(fil_ori_5[i])
        
high_int_filament_6 = []
low_int_filament_6 = []
for i in range(len(fil_ori_6)):
    if fil_int_6[i] >= np.median(fil_int_6):
        high_int_filament_6.append(fil_ori_6[i])
    elif fil_int_6[i] < np.median(fil_int_6):
        low_int_filament_6.append(fil_ori_6[i])

# %%
plt.rcParams["font.size"] = 15
plt.title("lower right_-50km/s_-30km/s")
bins = np.linspace(-90,90,num=10)
plt.hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins = bins)
plt.hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins = bins)

plt.rcParams["font.size"] = 10
plt.legend(loc='upper left')

plt.savefig("/home/filament/Desktop/lower right_-50_-30.jpg")

# %%
fig,ax = plt.subplots(3,2,figsize=(16,16))

bins = np.linspace(-90,90,num=10)


ax[0,0].set_title("lower right_30km/s_50km/s")
ax[0,0].hist(high_int_filament_1,alpha = 0.5, label='high intensity',bins=bins)
ax[0,0].hist(low_int_filament_1,alpha = 0.5, label='low intensity',bins=bins)
ax[0,0].legend(loc='upper left')

ax[0,1].set_title("lower right_50km/s_70km/s")
ax[0,1].hist(high_int_filament_2,alpha = 0.5, label='high intensity',bins=bins)
ax[0,1].hist(low_int_filament_2,alpha = 0.5, label='low intensity',bins=bins)
ax[0,1].legend(loc='upper left')

ax[1,0].set_title("lower right_70km/s_100km/s")
ax[1,0].hist(high_int_filament_3,alpha = 0.5, label='high intensity',bins=bins)
ax[1,0].hist(low_int_filament_3,alpha = 0.5, label='low intensity',bins=bins)
ax[1,0].legend(loc='upper left')

ax[1,1].set_title("lower right_-100km/s_-70km/s")
ax[1,1].hist(high_int_filament_4,alpha = 0.5, label='high intensity',bins=bins)
ax[1,1].hist(low_int_filament_4,alpha = 0.5, label='low intensity',bins=bins)
ax[1,1].legend(loc='upper left')

ax[2,0].set_title("lower right_-70km/s_-50km/s")
ax[2,0].hist(high_int_filament_5,alpha = 0.5, label='high intensity',bins=bins)
ax[2,0].hist(low_int_filament_5,alpha = 0.5, label='low intensity',bins=bins)
ax[2,0].legend(loc='upper left')


ax[2,1].set_title("lower right_-50km/s_-30km/s")
ax[2,1].hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins=bins)
ax[2,1].hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins=bins)
ax[2,1].legend(loc='upper left')

# %% [markdown]
# region3(30~50km/s) upper left
#
# region3(50~70km/s)
#
# region3(70~100km/s)
#
# region3(-100~-70km/s)
#
# region3(-70~-50km/s)
#
# region3(-50~-30km/s)

# %%
fil_ori_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/ori_test_3_30_50.npy")
fil_int_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/tot_int_test_3_30_50.npy")
fil_popt_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/popt_test_3_30_50.npy")
fil_pcov_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/pcov_test_3_30_50.npy")

fil_ori_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/ori_test_3_50_70.npy")
fil_int_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/tot_int_test_3_50_70.npy")
fil_popt_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/popt_test_3_50_70.npy")
fil_pcov_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/pcov_test_3_50_70.npy")

fil_ori_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/ori_test_3_70_100.npy")
fil_int_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/tot_int_test_3_70_100.npy")
fil_popt_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/popt_test_3_70_100.npy")
fil_pcov_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/pcov_test_3_70_100.npy")

fil_ori_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/ori_test_3_-100_-70.npy")
fil_int_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/tot_int_test_3_-100_-70.npy")
fil_popt_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/popt_test_3_-100_-70.npy")
fil_pcov_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/pcov_test_3_-100_-70.npy")

fil_ori_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/ori_test_3_-70_-50.npy")
fil_int_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/tot_int_test_3_-70_-50.npy")
fil_popt_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/popt_test_3_-70_-50.npy")
fil_pcov_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/pcov_test_3_-70_-50.npy")

fil_ori_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/ori_test_3_-50_-30.npy")
fil_int_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/tot_int_test_3_-50_-30.npy")
fil_popt_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/popt_test_3_-50_-30.npy")
fil_pcov_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region3/pcov_test_3_-50_-30.npy")

# %%
list = [
  [fil_popt_1[1], fil_popt_1[0],fil_popt_1[1],fil_popt_1[2], [fil_pcov_1[0][0],fil_pcov_1[1][1],fil_pcov_1[2][2]], np.min(fil_int_1),np.max(fil_int_1),np.median(fil_int_1)], 
  [fil_popt_2[1], fil_popt_2[0],fil_popt_2[1],fil_popt_2[2], [fil_pcov_2[0][0],fil_pcov_2[1][1],fil_pcov_2[2][2]], np.min(fil_int_2),np.max(fil_int_2),np.median(fil_int_2)],
  [fil_popt_3[1], fil_popt_3[0],fil_popt_3[1],fil_popt_3[2], [fil_pcov_3[0][0],fil_pcov_3[1][1],fil_pcov_3[2][2]], np.min(fil_int_3),np.max(fil_int_3),np.median(fil_int_3)], 
  [fil_popt_4[1], fil_popt_4[0],fil_popt_4[1],fil_popt_4[2], [fil_pcov_4[0][0],fil_pcov_4[1][1],fil_pcov_4[2][2]], np.min(fil_int_4),np.max(fil_int_4),np.median(fil_int_4)], 
  [fil_popt_5[1], fil_popt_5[0],fil_popt_5[1],fil_popt_5[2], [fil_pcov_5[0][0],fil_pcov_5[1][1],fil_pcov_5[2][2]], np.min(fil_int_5),np.max(fil_int_5),np.median(fil_int_5)], 
  [fil_popt_6[1], fil_popt_6[0],fil_popt_6[1],fil_popt_6[2], [fil_pcov_6[0][0],fil_pcov_6[1][1],fil_pcov_6[2][2]], np.min(fil_int_6),np.max(fil_int_6),np.median(fil_int_6)]
]

# %%
df = pd.DataFrame(list)
df.index = ['30~50km/s','50~70km/s','70~100km/s','-100~-70km/s','-70~-50km/s','-50~-30km/s']
df.columns = ['position angle(mode)','amplitude','offset','sigma','covariance','total intensity(min)','total intensity(max)','total intensity(median)']
df.style.set_caption("upper left")
# Out:
# <style type="text/css">
# </style>
# <table id="T_e101b_">
#   <caption>upper left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >position angle(mode)</th>
#       <th class="col_heading level0 col1" >amplitude</th>
#       <th class="col_heading level0 col2" >offset</th>
#       <th class="col_heading level0 col3" >sigma</th>
#       <th class="col_heading level0 col4" >covariance</th>
#       <th class="col_heading level0 col5" >total intensity(min)</th>
#       <th class="col_heading level0 col6" >total intensity(max)</th>
#       <th class="col_heading level0 col7" >total intensity(median)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e101b_level0_row0" class="row_heading level0 row0" >30~50km/s</th>
#       <td id="T_e101b_row0_col0" class="data row0 col0" >-13.470972</td>
#       <td id="T_e101b_row0_col1" class="data row0 col1" >29.358305</td>
# ...

# %%
high_int_filament_1 = []
low_int_filament_1 = []
for i in range(len(fil_ori_1)):
    if fil_int_1[i] >= np.median(fil_int_1):
        high_int_filament_1.append(fil_ori_1[i])
    elif fil_int_1[i] < np.median(fil_int_1):
        low_int_filament_1.append(fil_ori_1[i])
        
high_int_filament_2 = []
low_int_filament_2 = []
for i in range(len(fil_ori_2)):
    if fil_int_2[i] >= np.median(fil_int_2):
        high_int_filament_2.append(fil_ori_2[i])
    elif fil_int_2[i] < np.median(fil_int_2):
        low_int_filament_2.append(fil_ori_2[i])
        
high_int_filament_3 = []
low_int_filament_3 = []
for i in range(len(fil_ori_3)):
    if fil_int_3[i] >= np.median(fil_int_3):
        high_int_filament_3.append(fil_ori_3[i])
    elif fil_int_3[i] < np.median(fil_int_3):
        low_int_filament_3.append(fil_ori_3[i])

high_int_filament_4 = []
low_int_filament_4 = []
for i in range(len(fil_ori_4)):
    if fil_int_4[i] >= np.median(fil_int_4):
        high_int_filament_4.append(fil_ori_4[i])
    elif fil_int_4[i] < np.median(fil_int_4):
        low_int_filament_4.append(fil_ori_4[i])
        
high_int_filament_5 = []
low_int_filament_5 = []
for i in range(len(fil_ori_5)):
    if fil_int_5[i] >= np.median(fil_int_5):
        high_int_filament_5.append(fil_ori_5[i])
    elif fil_int_5[i] < np.median(fil_int_5):
        low_int_filament_5.append(fil_ori_5[i])
        
high_int_filament_6 = []
low_int_filament_6 = []
for i in range(len(fil_ori_6)):
    if fil_int_6[i] >= np.median(fil_int_6):
        high_int_filament_6.append(fil_ori_6[i])
    elif fil_int_6[i] < np.median(fil_int_6):
        low_int_filament_6.append(fil_ori_6[i])

# %%
plt.rcParams["font.size"] = 15
plt.title("upper left_-50km/s_-30km/s")
bins = np.linspace(-90,90,num=10)
plt.hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins = bins)
plt.hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins = bins)

plt.rcParams["font.size"] = 10
plt.legend(loc='upper left')

plt.savefig("/home/filament/Desktop/upper left_-50_-30.jpg")

# %%
fig,ax = plt.subplots(3,2,figsize=(16,16))


bins = np.linspace(-90,90,num=10)

ax[0,0].set_title("upper left_30km/s_50km/s")
ax[0,0].hist(high_int_filament_1,alpha = 0.5, label='high intensity',bins=bins)
ax[0,0].hist(low_int_filament_1,alpha = 0.5, label='low intensity',bins=bins)
ax[0,0].legend(loc='upper left')

ax[0,1].set_title("upper left_50km/s_70km/s")
ax[0,1].hist(high_int_filament_2,alpha = 0.5, label='high intensity',bins=bins)
ax[0,1].hist(low_int_filament_2,alpha = 0.5, label='low intensity',bins=bins)
ax[0,1].legend(loc='upper left')

ax[1,0].set_title("upper left_70km/s_100km/s")
ax[1,0].hist(high_int_filament_3,alpha = 0.5, label='high intensity',bins=bins)
ax[1,0].hist(low_int_filament_3,alpha = 0.5, label='low intensity',bins=bins)
ax[1,0].legend(loc='upper left')

ax[1,1].set_title("upper left_-100km/s_-70km/s")
ax[1,1].hist(high_int_filament_4,alpha = 0.5, label='high intensity',bins=bins)
ax[1,1].hist(low_int_filament_4,alpha = 0.5, label='low intensity',bins=bins)
ax[1,1].legend(loc='upper left')

ax[2,0].set_title("upper left_-70km/s_-50km/s")
ax[2,0].hist(high_int_filament_5,alpha = 0.5, label='high intensity',bins=bins)
ax[2,0].hist(low_int_filament_5,alpha = 0.5, label='low intensity',bins=bins)
ax[2,0].legend(loc='upper left')


ax[2,1].set_title("upper left_-50km/s_-30km/s")
ax[2,1].hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins=bins)
ax[2,1].hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins=bins)
ax[2,1].legend(loc='upper left')

# %% [markdown]
# region4(30~50km/s)  upper right
#
# region4(50~70km/s)
#
# region4(70~100km/s)
#
# region4(-100~-70km/s)
#
# region4(-70~-50km/s)
#
# region4(-50~-30km/s)

# %%
fil_ori_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/ori_test_4_30_50.npy")
fil_int_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/tot_int_test_4_30_50.npy")
fil_popt_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/popt_test_4_30_50.npy")
fil_pcov_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/pcov_test_4_30_50.npy")

fil_ori_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/ori_test_4_50_70.npy")
fil_int_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/tot_int_test_4_50_70.npy")
fil_popt_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/popt_test_4_50_70.npy")
fil_pcov_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/pcov_test_4_50_70.npy")

fil_ori_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/ori_test_4_70_100.npy")
fil_int_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/tot_int_test_4_70_100.npy")
fil_popt_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/popt_test_4_70_100.npy")
fil_pcov_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/pcov_test_4_70_100.npy")

fil_ori_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/ori_test_4_-100_-70.npy")
fil_int_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/tot_int_test_4_-100_-70.npy")
fil_popt_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/popt_test_4_-100_-70.npy")
fil_pcov_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/pcov_test_4_-100_-70.npy")

fil_ori_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/ori_test_4_-70_-50.npy")
fil_int_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/tot_int_test_4_-70_-50.npy")
fil_popt_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/popt_test_4_-70_-50.npy")
fil_pcov_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/pcov_test_4_-70_-50.npy")

fil_ori_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/ori_test_4_-50_-30.npy")
fil_int_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/tot_int_test_4_-50_-30.npy")
fil_popt_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/popt_test_4_-50_-30.npy")
fil_pcov_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region4/pcov_test_4_-50_-30.npy")

# %%
list = [
  [fil_popt_1[1], fil_popt_1[0],fil_popt_1[1],fil_popt_1[2], [fil_pcov_1[0][0],fil_pcov_1[1][1],fil_pcov_1[2][2]], np.min(fil_int_1),np.max(fil_int_1),np.median(fil_int_1)], 
  [fil_popt_2[1], fil_popt_2[0],fil_popt_2[1],fil_popt_2[2], [fil_pcov_2[0][0],fil_pcov_2[1][1],fil_pcov_2[2][2]], np.min(fil_int_2),np.max(fil_int_2),np.median(fil_int_2)],
  [fil_popt_3[1], fil_popt_3[0],fil_popt_3[1],fil_popt_3[2], [fil_pcov_3[0][0],fil_pcov_3[1][1],fil_pcov_3[2][2]], np.min(fil_int_3),np.max(fil_int_3),np.median(fil_int_3)], 
  [fil_popt_4[1], fil_popt_4[0],fil_popt_4[1],fil_popt_4[2], [fil_pcov_4[0][0],fil_pcov_4[1][1],fil_pcov_4[2][2]], np.min(fil_int_4),np.max(fil_int_4),np.median(fil_int_4)], 
  [fil_popt_5[1], fil_popt_5[0],fil_popt_5[1],fil_popt_5[2], [fil_pcov_5[0][0],fil_pcov_5[1][1],fil_pcov_5[2][2]], np.min(fil_int_5),np.max(fil_int_5),np.median(fil_int_5)], 
  [fil_popt_6[1], fil_popt_6[0],fil_popt_6[1],fil_popt_6[2], [fil_pcov_6[0][0],fil_pcov_6[1][1],fil_pcov_6[2][2]], np.min(fil_int_6),np.max(fil_int_6),np.median(fil_int_6)]
]

# %%
df = pd.DataFrame(list)
df.index = ['30~50km/s','50~70km/s','70~100km/s','-100~-70km/s','-70~-50km/s','-50~-30km/s']
df.columns = ['position angle(mode)','amplitude','offset','sigma','covariance','total intensity(min)','total intensity(max)','total intensity(median)']
df.style.set_caption("upper right")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6aee1_">
#   <caption>upper right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >position angle(mode)</th>
#       <th class="col_heading level0 col1" >amplitude</th>
#       <th class="col_heading level0 col2" >offset</th>
#       <th class="col_heading level0 col3" >sigma</th>
#       <th class="col_heading level0 col4" >covariance</th>
#       <th class="col_heading level0 col5" >total intensity(min)</th>
#       <th class="col_heading level0 col6" >total intensity(max)</th>
#       <th class="col_heading level0 col7" >total intensity(median)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aee1_level0_row0" class="row_heading level0 row0" >30~50km/s</th>
#       <td id="T_6aee1_row0_col0" class="data row0 col0" >10.253844</td>
#       <td id="T_6aee1_row0_col1" class="data row0 col1" >20.422642</td>
# ...

# %%
high_int_filament_1 = []
low_int_filament_1 = []
for i in range(len(fil_ori_1)):
    if fil_int_1[i] >= np.median(fil_int_1):
        high_int_filament_1.append(fil_ori_1[i])
    elif fil_int_1[i] < np.median(fil_int_1):
        low_int_filament_1.append(fil_ori_1[i])
        
high_int_filament_2 = []
low_int_filament_2 = []
for i in range(len(fil_ori_2)):
    if fil_int_2[i] >= np.median(fil_int_2):
        high_int_filament_2.append(fil_ori_2[i])
    elif fil_int_2[i] < np.median(fil_int_2):
        low_int_filament_2.append(fil_ori_2[i])
        
high_int_filament_3 = []
low_int_filament_3 = []
for i in range(len(fil_ori_3)):
    if fil_int_3[i] >= np.median(fil_int_3):
        high_int_filament_3.append(fil_ori_3[i])
    elif fil_int_3[i] < np.median(fil_int_3):
        low_int_filament_3.append(fil_ori_3[i])

high_int_filament_4 = []
low_int_filament_4 = []
for i in range(len(fil_ori_4)):
    if fil_int_4[i] >= np.median(fil_int_4):
        high_int_filament_4.append(fil_ori_4[i])
    elif fil_int_4[i] < np.median(fil_int_4):
        low_int_filament_4.append(fil_ori_4[i])
        
high_int_filament_5 = []
low_int_filament_5 = []
for i in range(len(fil_ori_5)):
    if fil_int_5[i] >= np.median(fil_int_5):
        high_int_filament_5.append(fil_ori_5[i])
    elif fil_int_5[i] < np.median(fil_int_5):
        low_int_filament_5.append(fil_ori_5[i])
        
high_int_filament_6 = []
low_int_filament_6 = []
for i in range(len(fil_ori_6)):
    if fil_int_6[i] >= np.median(fil_int_6):
        high_int_filament_6.append(fil_ori_6[i])
    elif fil_int_6[i] < np.median(fil_int_6):
        low_int_filament_6.append(fil_ori_6[i])

# %%
plt.rcParams["font.size"] = 15
plt.title("upper right_-50km/s_-30km/s")
bins = np.linspace(-90,90,num=10)
plt.hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins = bins)
plt.hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins = bins)

plt.rcParams["font.size"] = 10
plt.legend(loc='upper left')

plt.savefig("/home/filament/Desktop/upper right_-50_-30.jpg")

# %%
fig,ax = plt.subplots(3,2,figsize=(16,16))

bins = np.linspace(-90,90,num=10)

ax[0,0].set_title("upper right_30km/s_50km/s")
ax[0,0].hist(high_int_filament_1,alpha = 0.5, label='high intensity',bins=bins)
ax[0,0].hist(low_int_filament_1,alpha = 0.5, label='low intensity',bins=bins)
ax[0,0].legend(loc='upper left')

ax[0,1].set_title("upper right_50km/s_70km/s")
ax[0,1].hist(high_int_filament_2,alpha = 0.5, label='high intensity',bins=bins)
ax[0,1].hist(low_int_filament_2,alpha = 0.5, label='low intensity',bins=bins)
ax[0,1].legend(loc='upper left')

ax[1,0].set_title("upper right_70km/s_100km/s")
ax[1,0].hist(high_int_filament_3,alpha = 0.5, label='high intensity',bins=bins)
ax[1,0].hist(low_int_filament_3,alpha = 0.5, label='low intensity',bins=bins)
ax[1,0].legend(loc='upper left')

ax[1,1].set_title("upper right_-100km/s_-70km/s")
ax[1,1].hist(high_int_filament_4,alpha = 0.5, label='high intensity',bins=bins)
ax[1,1].hist(low_int_filament_4,alpha = 0.5, label='low intensity',bins=bins)
ax[1,1].legend(loc='upper left')

ax[2,0].set_title("upper right_-70km/s_-50km/s")
ax[2,0].hist(high_int_filament_5,alpha = 0.5, label='high intensity',bins=bins)
ax[2,0].hist(low_int_filament_5,alpha = 0.5, label='low intensity',bins=bins)
ax[2,0].legend(loc='upper left')


ax[2,1].set_title("upper right_-50km/s_-30km/s")
ax[2,1].hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins=bins)
ax[2,1].hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins=bins)
ax[2,1].legend(loc='upper left')

# %% [markdown]
# region5(30~50km/s)  lower middle
#
# region5(50~70km/s)
#
# region5(70~100km/s)
#
# region5(-100~-70km/s)
#
# region5(-70~-50km/s)
#
# region5(-50~-30km/s)

# %%
fil_ori_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/ori_test_5_30_50.npy")
fil_int_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/tot_int_test_5_30_50.npy")
fil_popt_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/popt_test_5_30_50.npy")
fil_pcov_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/pcov_test_5_30_50.npy")

fil_ori_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/ori_test_5_50_70.npy")
fil_int_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/tot_int_test_5_50_70.npy")
fil_popt_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/popt_test_5_50_70.npy")
fil_pcov_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/pcov_test_5_50_70.npy")

fil_ori_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/ori_test_5_70_100.npy")
fil_int_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/tot_int_test_5_70_100.npy")
fil_popt_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/popt_test_5_70_100.npy")
fil_pcov_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/pcov_test_5_70_100.npy")

fil_ori_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/ori_test_5_-100_-70.npy")
fil_int_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/tot_int_test_5_-100_-70.npy")
fil_popt_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/popt_test_5_-100_-70.npy")
fil_pcov_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/pcov_test_5_-100_-70.npy")

fil_ori_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/ori_test_5_-70_-50.npy")
fil_int_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/tot_int_test_5_-70_-50.npy")
fil_popt_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/popt_test_5_-70_-50.npy")
fil_pcov_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/pcov_test_5_-70_-50.npy")

fil_ori_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/ori_test_5_-50_-30.npy")
fil_int_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/tot_int_test_5_-50_-30.npy")
fil_popt_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/popt_test_5_-50_-30.npy")
fil_pcov_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region5/pcov_test_5_-50_-30.npy")

# %%
list = [
  [fil_popt_1[1], fil_popt_1[0],fil_popt_1[1],fil_popt_1[2], [fil_pcov_1[0][0],fil_pcov_1[1][1],fil_pcov_1[2][2]], np.min(fil_int_1),np.max(fil_int_1),np.median(fil_int_1)], 
  [fil_popt_2[1], fil_popt_2[0],fil_popt_2[1],fil_popt_2[2], [fil_pcov_2[0][0],fil_pcov_2[1][1],fil_pcov_2[2][2]], np.min(fil_int_2),np.max(fil_int_2),np.median(fil_int_2)],
  [fil_popt_3[1], fil_popt_3[0],fil_popt_3[1],fil_popt_3[2], [fil_pcov_3[0][0],fil_pcov_3[1][1],fil_pcov_3[2][2]], np.min(fil_int_3),np.max(fil_int_3),np.median(fil_int_3)], 
  [fil_popt_4[1], fil_popt_4[0],fil_popt_4[1],fil_popt_4[2], [fil_pcov_4[0][0],fil_pcov_4[1][1],fil_pcov_4[2][2]], np.min(fil_int_4),np.max(fil_int_4),np.median(fil_int_4)], 
  [fil_popt_5[1], fil_popt_5[0],fil_popt_5[1],fil_popt_5[2], [fil_pcov_5[0][0],fil_pcov_5[1][1],fil_pcov_5[2][2]], np.min(fil_int_5),np.max(fil_int_5),np.median(fil_int_5)], 
  [fil_popt_6[1], fil_popt_6[0],fil_popt_6[1],fil_popt_6[2], [fil_pcov_6[0][0],fil_pcov_6[1][1],fil_pcov_6[2][2]], np.min(fil_int_6),np.max(fil_int_6),np.median(fil_int_6)]
]

# %%
df = pd.DataFrame(list)
df.index = ['30~50km/s','50~70km/s','70~100km/s','-100~-70km/s','-70~-50km/s','-50~-30km/s']
df.columns = ['position angle(mode)','amplitude','offset','sigma','covariance','total intensity(min)','total intensity(max)','total intensity(median)']
df.style.set_caption("lower middle")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff877_">
#   <caption>lower middle</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >position angle(mode)</th>
#       <th class="col_heading level0 col1" >amplitude</th>
#       <th class="col_heading level0 col2" >offset</th>
#       <th class="col_heading level0 col3" >sigma</th>
#       <th class="col_heading level0 col4" >covariance</th>
#       <th class="col_heading level0 col5" >total intensity(min)</th>
#       <th class="col_heading level0 col6" >total intensity(max)</th>
#       <th class="col_heading level0 col7" >total intensity(median)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff877_level0_row0" class="row_heading level0 row0" >30~50km/s</th>
#       <td id="T_ff877_row0_col0" class="data row0 col0" >26.909230</td>
#       <td id="T_ff877_row0_col1" class="data row0 col1" >5.765399</td>
# ...

# %%
high_int_filament_1 = []
low_int_filament_1 = []
for i in range(len(fil_ori_1)):
    if fil_int_1[i] >= np.median(fil_int_1):
        high_int_filament_1.append(fil_ori_1[i])
    elif fil_int_1[i] < np.median(fil_int_1):
        low_int_filament_1.append(fil_ori_1[i])
        
high_int_filament_2 = []
low_int_filament_2 = []
for i in range(len(fil_ori_2)):
    if fil_int_2[i] >= np.median(fil_int_2):
        high_int_filament_2.append(fil_ori_2[i])
    elif fil_int_2[i] < np.median(fil_int_2):
        low_int_filament_2.append(fil_ori_2[i])
        
high_int_filament_3 = []
low_int_filament_3 = []
for i in range(len(fil_ori_3)):
    if fil_int_3[i] >= np.median(fil_int_3):
        high_int_filament_3.append(fil_ori_3[i])
    elif fil_int_3[i] < np.median(fil_int_3):
        low_int_filament_3.append(fil_ori_3[i])

high_int_filament_4 = []
low_int_filament_4 = []
for i in range(len(fil_ori_4)):
    if fil_int_4[i] >= np.median(fil_int_4):
        high_int_filament_4.append(fil_ori_4[i])
    elif fil_int_4[i] < np.median(fil_int_4):
        low_int_filament_4.append(fil_ori_4[i])
        
high_int_filament_5 = []
low_int_filament_5 = []
for i in range(len(fil_ori_5)):
    if fil_int_5[i] >= np.median(fil_int_5):
        high_int_filament_5.append(fil_ori_5[i])
    elif fil_int_5[i] < np.median(fil_int_5):
        low_int_filament_5.append(fil_ori_5[i])
        
high_int_filament_6 = []
low_int_filament_6 = []
for i in range(len(fil_ori_6)):
    if fil_int_6[i] >= np.median(fil_int_6):
        high_int_filament_6.append(fil_ori_6[i])
    elif fil_int_6[i] < np.median(fil_int_6):
        low_int_filament_6.append(fil_ori_6[i])

# %%
plt.rcParams["font.size"] = 15
plt.title("lower middle_-50km/s_-30km/s")
bins = np.linspace(-90,90,num=10)
plt.hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins = bins)
plt.hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins = bins)

plt.rcParams["font.size"] = 10
plt.legend(loc='upper left')

plt.savefig("/home/filament/Desktop/lower middle_-50_-30.jpg")

# %%
fig,ax = plt.subplots(3,2,figsize=(16,16))

bins = np.linspace(-90,90,num=10)

ax[0,0].set_title("lower middle_30km/s_50km/s")
ax[0,0].hist(high_int_filament_1,alpha = 0.5, label='high intensity',bins=bins)
ax[0,0].hist(low_int_filament_1,alpha = 0.5, label='low intensity',bins=bins)
ax[0,0].legend(loc='upper left')

ax[0,1].set_title("lower middle_50km/s_70km/s")
ax[0,1].hist(high_int_filament_2,alpha = 0.5, label='high intensity',bins=bins)
ax[0,1].hist(low_int_filament_2,alpha = 0.5, label='low intensity',bins=bins)
ax[0,1].legend(loc='upper left')

ax[1,0].set_title("lower middle_70km/s_100km/s")
ax[1,0].hist(high_int_filament_3,alpha = 0.5, label='high intensity',bins=bins)
ax[1,0].hist(low_int_filament_3,alpha = 0.5, label='low intensity',bins=bins)
ax[1,0].legend(loc='upper left')

ax[1,1].set_title("lower middle_-100km/s_-70km/s")
ax[1,1].hist(high_int_filament_4,alpha = 0.5, label='high intensity',bins=bins)
ax[1,1].hist(low_int_filament_4,alpha = 0.5, label='low intensity',bins=bins)
ax[1,1].legend(loc='upper left')

ax[2,0].set_title("lower middle_-70km/s_-50km/s")
ax[2,0].hist(high_int_filament_5,alpha = 0.5, label='high intensity',bins=bins)
ax[2,0].hist(low_int_filament_5,alpha = 0.5, label='low intensity',bins=bins)
ax[2,0].legend(loc='upper left')


ax[2,1].set_title("lower middle_-50km/s_-30km/s")
ax[2,1].hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins=bins)
ax[2,1].hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins=bins)
ax[2,1].legend(loc='upper left')

# %% [markdown]
# region6  upper middle

# %%
fil_ori_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/ori_test_6_30_50.npy")
fil_int_1 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/tot_int_test_6_30_50.npy")
# fil_popt_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/popt_test_6_30_50.npy")
fil_popt_1 = ['error','error','error']
# fil_pcov_1 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/pcov_test_6_30_50.npy")
fil_pcov_1 = [['error','error','error'],['error','error','error'],['error','error','error']]

fil_ori_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/ori_test_6_50_70.npy")
fil_int_2 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/tot_int_test_6_50_70.npy")
fil_popt_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/popt_test_6_50_70.npy")
fil_pcov_2 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/pcov_test_6_50_70.npy")

fil_ori_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/ori_test_6_70_100.npy")
fil_int_3 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/tot_int_test_6_70_100.npy")
fil_popt_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/popt_test_6_70_100.npy")
fil_pcov_3 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/pcov_test_6_70_100.npy")

fil_ori_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/ori_test_6_-100_-70.npy")
fil_int_4 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/tot_int_test_6_-100_-70.npy")
# fil_popt_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/popt_test_6_-100_-70.npy")
fil_popt_4 = ['error','error','error']
# fil_pcov_4 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/pcov_test_6_-100_-70.npy")
fil_pcov_4 = [['error','error','error'],['error','error','error'],['error','error','error']]

fil_ori_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/ori_test_6_-70_-50.npy")
fil_int_5 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/tot_int_test_6_-70_-50.npy")
fil_popt_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/popt_test_6_-70_-50.npy")
fil_pcov_5 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/pcov_test_6_-70_-50.npy")

fil_ori_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/ori_test_6_-50_-30.npy")
fil_int_6 = np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/tot_int_test_6_-50_-30.npy")
fil_popt_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/popt_test_6_-50_-30.npy")
fil_pcov_6 =np.load("/home/filament/Desktop/fil-test/fil_finder.png/AIT/region6/pcov_test_6_-50_-30.npy")

# %%
list = [
  [fil_popt_1[1], fil_popt_1[0],fil_popt_1[1],fil_popt_1[2], [fil_pcov_1[0][0],fil_pcov_1[1][1],fil_pcov_1[2][2]], np.min(fil_int_1),np.max(fil_int_1),np.median(fil_int_1)], 
  [fil_popt_2[1], fil_popt_2[0],fil_popt_2[1],fil_popt_2[2], [fil_pcov_2[0][0],fil_pcov_2[1][1],fil_pcov_2[2][2]], np.min(fil_int_2),np.max(fil_int_2),np.median(fil_int_2)],
  [fil_popt_3[1], fil_popt_3[0],fil_popt_3[1],fil_popt_3[2], [fil_pcov_3[0][0],fil_pcov_3[1][1],fil_pcov_3[2][2]], np.min(fil_int_3),np.max(fil_int_3),np.median(fil_int_3)], 
  [fil_popt_4[1], fil_popt_4[0],fil_popt_4[1],fil_popt_4[2], [fil_pcov_4[0][0],fil_pcov_4[1][1],fil_pcov_4[2][2]], np.min(fil_int_4),np.max(fil_int_4),np.median(fil_int_4)], 
  [fil_popt_5[1], fil_popt_5[0],fil_popt_5[1],fil_popt_5[2], [fil_pcov_5[0][0],fil_pcov_5[1][1],fil_pcov_5[2][2]], np.min(fil_int_5),np.max(fil_int_5),np.median(fil_int_5)], 
  [fil_popt_6[1], fil_popt_6[0],fil_popt_6[1],fil_popt_6[2], [fil_pcov_6[0][0],fil_pcov_6[1][1],fil_pcov_6[2][2]], np.min(fil_int_6),np.max(fil_int_6),np.median(fil_int_6)]
]

# %%
df = pd.DataFrame(list)
df.index = ['30~50km/s','50~70km/s','70~100km/s','-100~-70km/s','-70~-50km/s','-50~-30km/s']
df.columns = ['position angle(mode)','amplitude','offset','sigma','covariance','total intensity(min)','total intensity(max)','total intensity(median)']
df.style.set_caption("upper middle")
# Out:
# <style type="text/css">
# </style>
# <table id="T_33d1d_">
#   <caption>upper middle</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >position angle(mode)</th>
#       <th class="col_heading level0 col1" >amplitude</th>
#       <th class="col_heading level0 col2" >offset</th>
#       <th class="col_heading level0 col3" >sigma</th>
#       <th class="col_heading level0 col4" >covariance</th>
#       <th class="col_heading level0 col5" >total intensity(min)</th>
#       <th class="col_heading level0 col6" >total intensity(max)</th>
#       <th class="col_heading level0 col7" >total intensity(median)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33d1d_level0_row0" class="row_heading level0 row0" >30~50km/s</th>
#       <td id="T_33d1d_row0_col0" class="data row0 col0" >error</td>
#       <td id="T_33d1d_row0_col1" class="data row0 col1" >error</td>
# ...

# %%
high_int_filament_1 = []
low_int_filament_1 = []
for i in range(len(fil_ori_1)):
    if fil_int_1[i] >= np.median(fil_int_1):
        high_int_filament_1.append(fil_ori_1[i])
    elif fil_int_1[i] < np.median(fil_int_1):
        low_int_filament_1.append(fil_ori_1[i])
        
high_int_filament_2 = []
low_int_filament_2 = []
for i in range(len(fil_ori_2)):
    if fil_int_2[i] >= np.median(fil_int_2):
        high_int_filament_2.append(fil_ori_2[i])
    elif fil_int_2[i] < np.median(fil_int_2):
        low_int_filament_2.append(fil_ori_2[i])
        
high_int_filament_3 = []
low_int_filament_3 = []
for i in range(len(fil_ori_3)):
    if fil_int_3[i] >= np.median(fil_int_3):
        high_int_filament_3.append(fil_ori_3[i])
    elif fil_int_3[i] < np.median(fil_int_3):
        low_int_filament_3.append(fil_ori_3[i])

high_int_filament_4 = []
low_int_filament_4 = []
for i in range(len(fil_ori_4)):
    if fil_int_4[i] >= np.median(fil_int_4):
        high_int_filament_4.append(fil_ori_4[i])
    elif fil_int_4[i] < np.median(fil_int_4):
        low_int_filament_4.append(fil_ori_4[i])
        
high_int_filament_5 = []
low_int_filament_5 = []
for i in range(len(fil_ori_5)):
    if fil_int_5[i] >= np.median(fil_int_5):
        high_int_filament_5.append(fil_ori_5[i])
    elif fil_int_5[i] < np.median(fil_int_5):
        low_int_filament_5.append(fil_ori_5[i])
        
high_int_filament_6 = []
low_int_filament_6 = []
for i in range(len(fil_ori_6)):
    if fil_int_6[i] >= np.median(fil_int_6):
        high_int_filament_6.append(fil_ori_6[i])
    elif fil_int_6[i] < np.median(fil_int_6):
        low_int_filament_6.append(fil_ori_6[i])

# %%
plt.rcParams["font.size"] = 15
plt.title("upper middle_-50km/s_-30km/s")
bins = np.linspace(-90,90,num=10)
plt.hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins = bins)
plt.hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins = bins)

plt.rcParams["font.size"] = 10
plt.legend(loc='upper left')

plt.savefig("/home/filament/Desktop/upper middle_-50_-30.jpg")

# %%
fig,ax = plt.subplots(3,2,figsize=(16,16))

bins = np.linspace(-90,90,num=10)

ax[0,0].set_title("upper middle_30km/s_50km/s")
ax[0,0].hist(high_int_filament_1,alpha = 0.5, label='high intensity',bins=bins)
ax[0,0].hist(low_int_filament_1,alpha = 0.5, label='low intensity',bins=bins)
ax[0,0].legend(loc='upper left')

ax[0,1].set_title("upper middle_50km/s_70km/s")
ax[0,1].hist(high_int_filament_2,alpha = 0.5, label='high intensity',bins=bins)
ax[0,1].hist(low_int_filament_2,alpha = 0.5, label='low intensity',bins=bins)
ax[0,1].legend(loc='upper left')

ax[1,0].set_title("upper middle_70km/s_100km/s")
ax[1,0].hist(high_int_filament_3,alpha = 0.5, label='high intensity',bins=bins)
ax[1,0].hist(low_int_filament_3,alpha = 0.5, label='low intensity',bins=bins)
ax[1,0].legend(loc='upper left')

ax[1,1].set_title("upper middle_-100km/s_-70km/s")
ax[1,1].hist(high_int_filament_4,alpha = 0.5, label='high intensity',bins=bins)
ax[1,1].hist(low_int_filament_4,alpha = 0.5, label='low intensity',bins=bins)
ax[1,1].legend(loc='upper left')

ax[2,0].set_title("upper middle_-70km/s_-50km/s")
ax[2,0].hist(high_int_filament_5,alpha = 0.5, label='high intensity',bins=bins)
ax[2,0].hist(low_int_filament_5,alpha = 0.5, label='low intensity',bins=bins)
ax[2,0].legend(loc='upper left')


ax[2,1].set_title("upper middle_-50km/s_-30km/s")
ax[2,1].hist(high_int_filament_6,alpha = 0.5, label='high intensity',bins=bins)
ax[2,1].hist(low_int_filament_6,alpha = 0.5, label='low intensity',bins=bins)
ax[2,1].legend(loc='upper left')
